# %% [markdown]
# ## 範例目標
#
# * 比較 CNN 與 DNN 參數量和準確度的差異

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score
from keras import backend
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from keras.optimizers import RMSprop
tf.logging.set_verbosity(tf.logging.ERROR)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 準備資料

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
def normalize_cifar10_data(x, y):
    x = x / 255.
    y = np_utils.to_categorical(y, num_classes=10)
    return x, y

def normalize_result(x, y):
    print('x.shape:', x.shape)
    print('y.shape:', y.shape)

# %%
print('Before normalization:')
normalize_result(X_train, y_train)
# Out:
# Before normalization:
# x.shape: (50000, 32, 32, 3)
# y.shape: (50000, 1)

# %%
print('After normalization:')
X_train, y_train = normalize_cifar10_data(X_train, y_train)
X_test, y_test = normalize_cifar10_data(X_test, y_test)
normalize_result(X_train, y_train)
# Out:
# After normalization:
# x.shape: (50000, 32, 32, 3)
# y.shape: (50000, 10)

# %% [markdown]
# ## 定義函數

# %%
class AbstractTrainer:

    def __init__(self, X_train, y_train, X_test, y_test, epochs=50, batch_size=128, learning_rate=1e-3):
        self.X_test = X_test
        self.y_test = y_test
        self.X_train = X_train
        self.y_train = y_train
        self.epochs = epochs
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self._model = None
        self._history = None

    @property
    def optimizer(self):
        return RMSprop(lr=self.learning_rate)

    @property
    def validation_data(self):
        return (self.X_test, self.y_test,)

    def run(self):
        return self._clear()._build()._launch()

    def _clear(self):
        backend.clear_session()
        self._model = None
        return self

    def _build(self):
        raise NotImplementedError('`{}` method `{}` hasn\'t been implemented.'.format(self, '_build'))

    def _launch(self):
        print('Experiment with trainer: {}'.format(self.__class__.__name__))
        self._model.summary()
        self._history = self._model.fit(
            self.X_train, self.y_train, epochs=self.epochs, batch_size=self.batch_size,
            validation_data=self.validation_data, shuffle=True, verbose=2)
        return self

    def display(self, train_name, val_name):
        plt.figure(figsize=(8, 6,))
        plt.plot(self._history.history[train_name])
        plt.plot(self._history.history[val_name])
        plt.xlabel('Epoch')
        plt.ylabel(train_name)
        plt.title('Train History')
        plt.legend(['train', 'validation'], loc='upper left')
        plt.show()

class CNNTrainer(AbstractTrainer):
    
    def _build(self):
        model = self._model = Sequential()
        model.add(Conv2D(32, (3, 3,), padding='same', input_shape=self.X_train.shape[1:]))
        model.add(Activation('relu'))
        model.add(Conv2D(32, (3, 3,)))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2,)))
        model.add(Dropout(0.25))
        model.add(Conv2D(64, (3, 3,), padding='same'))
        model.add(Activation('relu'))
        model.add(Conv2D(64, (3, 3,)))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2,)))
        model.add(Dropout(0.25))
        model.add(Flatten())
        model.add(Dense(512))
        model.add(Activation('relu'))
        model.add(Dropout(0.50))
        model.add(Dense(self.y_train.shape[-1]))
        model.add(Activation('softmax'))
        model.compile(optimizer=self.optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
        return self

class DNNTrainer(AbstractTrainer):
    
    def _build(self):
        model = self._model = Sequential()
        model.add(Flatten(input_shape=self.X_train.shape[1:]))
        model.add(Dense(512))
        model.add(Activation('relu'))
        model.add(Dropout(0.20))
        model.add(Dense(512))
        model.add(Activation('relu'))
        model.add(Dropout(0.20))
        model.add(Dense(self.y_train.shape[-1]))
        model.add(Activation('softmax'))
        model.compile(optimizer=self.optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
        return self

# %% [markdown]
# ## DNN
#
# 由於 DNN 只能輸入一維資料，必須先將影像進行攤平，維度 (50000, 32, 32, 3) 的影像攤平後會變成 (50000, 3072)。

# %%
trainer = DNNTrainer(X_train, y_train, X_test, y_test).run()
# Out:
# Experiment with trainer: DNNTrainer
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_2 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#  - 23s - loss: 2.1788 - acc: 0.2466 - val_loss: 1.8403 - val_acc: 0.3389
# Epoch 2/50
#  - 23s - loss: 1.8506 - acc: 0.3309 - val_loss: 1.7127 - val_acc: 0.3992
# Epoch 3/50
#  - 23s - loss: 1.7764 - acc: 0.3601 - val_loss: 1.9316 - val_acc: 0.3070
# Epoch 4/50
#  - 23s - loss: 1.7239 - acc: 0.3801 - val_loss: 1.6668 - val_acc: 0.4059
# Epoch 5/50
#  - 23s - loss: 1.6842 - acc: 0.3942 - val_loss: 1.6110 - val_acc: 0.4386
# Epoch 6/50
#  - 23s - loss: 1.6591 - acc: 0.4048 - val_loss: 1.6341 - val_acc: 0.4203
# Epoch 7/50
#  - 23s - loss: 1.6316 - acc: 0.4157 - val_loss: 1.5680 - val_acc: 0.4553
# Epoch 8/50
#  - 23s - loss: 1.6106 - acc: 0.4246 - val_loss: 1.5566 - val_acc: 0.4386
# Epoch 9/50
#  - 23s - loss: 1.5978 - acc: 0.4262 - val_loss: 1.6174 - val_acc: 0.4236
# Epoch 10/50
#  - 23s - loss: 1.5769 - acc: 0.4376 - val_loss: 1.5244 - val_acc: 0.4737
# Epoch 11/50
#  - 23s - loss: 1.5719 - acc: 0.4411 - val_loss: 1.5098 - val_acc: 0.4650
# Epoch 12/50
#  - 23s - loss: 1.5549 - acc: 0.4445 - val_loss: 1.5289 - val_acc: 0.4624
# Epoch 13/50
#  - 23s - loss: 1.5426 - acc: 0.4504 - val_loss: 1.6159 - val_acc: 0.4149
# Epoch 14/50
#  - 23s - loss: 1.5409 - acc: 0.4479 - val_loss: 1.5133 - val_acc: 0.4654
# Epoch 15/50
#  - 23s - loss: 1.5360 - acc: 0.4537 - val_loss: 1.5058 - val_acc: 0.4778
# Epoch 16/50
#  - 23s - loss: 1.5265 - acc: 0.4552 - val_loss: 1.5555 - val_acc: 0.4402
# Epoch 17/50
#  - 23s - loss: 1.5196 - acc: 0.4588 - val_loss: 1.5091 - val_acc: 0.4653
# Epoch 18/50
#  - 23s - loss: 1.5129 - acc: 0.4604 - val_loss: 1.4938 - val_acc: 0.4704
# Epoch 19/50
#  - 23s - loss: 1.5005 - acc: 0.4681 - val_loss: 1.4978 - val_acc: 0.4679
# Epoch 20/50
#  - 23s - loss: 1.5050 - acc: 0.4655 - val_loss: 1.5405 - val_acc: 0.4487
# Epoch 21/50
#  - 23s - loss: 1.4968 - acc: 0.4647 - val_loss: 1.4985 - val_acc: 0.4760
# Epoch 22/50
#  - 23s - loss: 1.4932 - acc: 0.4698 - val_loss: 1.5032 - val_acc: 0.4677
# Epoch 23/50
#  - 23s - loss: 1.4881 - acc: 0.4711 - val_loss: 1.4781 - val_acc: 0.4792
# Epoch 24/50
#  - 23s - loss: 1.4869 - acc: 0.4706 - val_loss: 1.5004 - val_acc: 0.4636
# Epoch 25/50
#  - 23s - loss: 1.4757 - acc: 0.4743 - val_loss: 1.4607 - val_acc: 0.4902
# Epoch 26/50
#  - 23s - loss: 1.4747 - acc: 0.4764 - val_loss: 1.4760 - val_acc: 0.4859
# Epoch 27/50
#  - 23s - loss: 1.4674 - acc: 0.4774 - val_loss: 1.5065 - val_acc: 0.4617
# Epoch 28/50
#  - 23s - loss: 1.4653 - acc: 0.4810 - val_loss: 1.4904 - val_acc: 0.4750
# Epoch 29/50
#  - 23s - loss: 1.4706 - acc: 0.4796 - val_loss: 1.5161 - val_acc: 0.4749
# Epoch 30/50
#  - 23s - loss: 1.4633 - acc: 0.4802 - val_loss: 1.4555 - val_acc: 0.4831
# Epoch 31/50
#  - 23s - loss: 1.4529 - acc: 0.4845 - val_loss: 1.4478 - val_acc: 0.4823
# Epoch 32/50
#  - 23s - loss: 1.4550 - acc: 0.4863 - val_loss: 1.4675 - val_acc: 0.4766
# Epoch 33/50
#  - 23s - loss: 1.4496 - acc: 0.4870 - val_loss: 1.4603 - val_acc: 0.4804
# Epoch 34/50
#  - 23s - loss: 1.4535 - acc: 0.4872 - val_loss: 1.4843 - val_acc: 0.4860
# Epoch 35/50
#  - 23s - loss: 1.4482 - acc: 0.4869 - val_loss: 1.4598 - val_acc: 0.4879
# Epoch 36/50
#  - 23s - loss: 1.4480 - acc: 0.4881 - val_loss: 1.4833 - val_acc: 0.4757
# Epoch 37/50
#  - 23s - loss: 1.4470 - acc: 0.4897 - val_loss: 1.4938 - val_acc: 0.4794
# Epoch 38/50
#  - 23s - loss: 1.4417 - acc: 0.4894 - val_loss: 1.4299 - val_acc: 0.5003
# Epoch 39/50
#  - 24s - loss: 1.4424 - acc: 0.4907 - val_loss: 1.4476 - val_acc: 0.4849
# Epoch 40/50
#  - 23s - loss: 1.4362 - acc: 0.4911 - val_loss: 1.4283 - val_acc: 0.4979
# Epoch 41/50
#  - 22s - loss: 1.4353 - acc: 0.4924 - val_loss: 1.5041 - val_acc: 0.4599
# Epoch 42/50
#  - 22s - loss: 1.4305 - acc: 0.4946 - val_loss: 1.4979 - val_acc: 0.4771
# Epoch 43/50
#  - 23s - loss: 1.4376 - acc: 0.4911 - val_loss: 1.4781 - val_acc: 0.4745
# Epoch 44/50
#  - 23s - loss: 1.4268 - acc: 0.4964 - val_loss: 1.4433 - val_acc: 0.4864
# Epoch 45/50
#  - 22s - loss: 1.4292 - acc: 0.4973 - val_loss: 1.5017 - val_acc: 0.4832
# Epoch 46/50
#  - 22s - loss: 1.4290 - acc: 0.4963 - val_loss: 1.5326 - val_acc: 0.4614
# Epoch 47/50
#  - 22s - loss: 1.4211 - acc: 0.4969 - val_loss: 1.5456 - val_acc: 0.4469
# Epoch 48/50
#  - 22s - loss: 1.4217 - acc: 0.4956 - val_loss: 1.5337 - val_acc: 0.4608
# Epoch 49/50
#  - 22s - loss: 1.4242 - acc: 0.4971 - val_loss: 1.4931 - val_acc: 0.4701
# Epoch 50/50
#  - 24s - loss: 1.4226 - acc: 0.4977 - val_loss: 1.5184 - val_acc: 0.4516

# %%
trainer.display('acc', 'val_acc')

# %%
trainer.display('loss', 'val_loss')

# %% [markdown]
# ## CNN
#
# 由於 CNN 的原理非常適合處理影像類的資料，同樣的訓練條件，CNN 是否顯著優於 DNN 呢？

# %%
trainer = CNNTrainer(X_train, y_train, X_test, y_test).run()
# Out:
# Experiment with trainer: CNNTrainer
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_6 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#  - 181s - loss: 1.7470 - acc: 0.3685 - val_loss: 1.4805 - val_acc: 0.4657
# Epoch 2/50
#  - 179s - loss: 1.3114 - acc: 0.5357 - val_loss: 1.0807 - val_acc: 0.6184
# Epoch 3/50
#  - 175s - loss: 1.1054 - acc: 0.6124 - val_loss: 0.9903 - val_acc: 0.6466
# Epoch 4/50
#  - 174s - loss: 0.9770 - acc: 0.6612 - val_loss: 0.8618 - val_acc: 0.7034
# Epoch 5/50
#  - 174s - loss: 0.8830 - acc: 0.6926 - val_loss: 0.8108 - val_acc: 0.7190
# Epoch 6/50
#  - 172s - loss: 0.8180 - acc: 0.7159 - val_loss: 0.8730 - val_acc: 0.6995
# Epoch 7/50
#  - 172s - loss: 0.7615 - acc: 0.7372 - val_loss: 0.8351 - val_acc: 0.7132
# Epoch 8/50
#  - 184s - loss: 0.7167 - acc: 0.7529 - val_loss: 0.8407 - val_acc: 0.7170
# Epoch 9/50
#  - 180s - loss: 0.6909 - acc: 0.7618 - val_loss: 0.6799 - val_acc: 0.7637
# Epoch 10/50
#  - 178s - loss: 0.6586 - acc: 0.7718 - val_loss: 0.7226 - val_acc: 0.7486
# Epoch 11/50
#  - 182s - loss: 0.6387 - acc: 0.7814 - val_loss: 0.7124 - val_acc: 0.7550
# Epoch 12/50
#  - 179s - loss: 0.6226 - acc: 0.7869 - val_loss: 0.7052 - val_acc: 0.7681
# Epoch 13/50
#  - 179s - loss: 0.6068 - acc: 0.7899 - val_loss: 0.6905 - val_acc: 0.7765
# Epoch 14/50
#  - 173s - loss: 0.6037 - acc: 0.7947 - val_loss: 0.7028 - val_acc: 0.7654
# Epoch 15/50
#  - 171s - loss: 0.6017 - acc: 0.7949 - val_loss: 0.7048 - val_acc: 0.7768
# Epoch 16/50
#  - 172s - loss: 0.5950 - acc: 0.7987 - val_loss: 0.7376 - val_acc: 0.7811
# Epoch 17/50
#  - 175s - loss: 0.5909 - acc: 0.7998 - val_loss: 0.7069 - val_acc: 0.7746
# Epoch 18/50
#  - 169s - loss: 0.5934 - acc: 0.8021 - val_loss: 0.7356 - val_acc: 0.7860
# Epoch 19/50
#  - 171s - loss: 0.5905 - acc: 0.8035 - val_loss: 0.7505 - val_acc: 0.7695
# Epoch 20/50
#  - 172s - loss: 0.5934 - acc: 0.8051 - val_loss: 0.6341 - val_acc: 0.7936
# Epoch 21/50
#  - 172s - loss: 0.5899 - acc: 0.8048 - val_loss: 0.7080 - val_acc: 0.7803
# Epoch 22/50
#  - 173s - loss: 0.5910 - acc: 0.8030 - val_loss: 0.7093 - val_acc: 0.7947
# Epoch 23/50
#  - 171s - loss: 0.5911 - acc: 0.8044 - val_loss: 0.6293 - val_acc: 0.7979
# Epoch 24/50
#  - 176s - loss: 0.5950 - acc: 0.8015 - val_loss: 0.7323 - val_acc: 0.7945
# Epoch 25/50
#  - 179s - loss: 0.6044 - acc: 0.8027 - val_loss: 0.6458 - val_acc: 0.7926
# Epoch 26/50
#  - 186s - loss: 0.6064 - acc: 0.8015 - val_loss: 0.7033 - val_acc: 0.7718
# Epoch 27/50
#  - 189s - loss: 0.6034 - acc: 0.8035 - val_loss: 0.7525 - val_acc: 0.7801
# Epoch 28/50
#  - 172s - loss: 0.6063 - acc: 0.8028 - val_loss: 0.7645 - val_acc: 0.7540
# Epoch 29/50
#  - 180s - loss: 0.6024 - acc: 0.8046 - val_loss: 0.6924 - val_acc: 0.7930
# Epoch 30/50
#  - 179s - loss: 0.6141 - acc: 0.7989 - val_loss: 0.6935 - val_acc: 0.7828
# Epoch 31/50
#  - 177s - loss: 0.6194 - acc: 0.8000 - val_loss: 0.6936 - val_acc: 0.7940
# Epoch 32/50
#  - 178s - loss: 0.6181 - acc: 0.8007 - val_loss: 0.7467 - val_acc: 0.7644
# Epoch 33/50
#  - 177s - loss: 0.6281 - acc: 0.7969 - val_loss: 0.7265 - val_acc: 0.7737
# Epoch 34/50
#  - 189s - loss: 0.6195 - acc: 0.8014 - val_loss: 0.7478 - val_acc: 0.7616
# Epoch 35/50
#  - 188s - loss: 0.6276 - acc: 0.7989 - val_loss: 0.8239 - val_acc: 0.7788
# Epoch 36/50
#  - 186s - loss: 0.6265 - acc: 0.7981 - val_loss: 0.6464 - val_acc: 0.7964
# Epoch 37/50
#  - 188s - loss: 0.6369 - acc: 0.7969 - val_loss: 0.7959 - val_acc: 0.7738
# Epoch 38/50
#  - 183s - loss: 0.6376 - acc: 0.7954 - val_loss: 0.7128 - val_acc: 0.7715
# Epoch 39/50
#  - 177s - loss: 0.6356 - acc: 0.7986 - val_loss: 0.7093 - val_acc: 0.7879
# Epoch 40/50
#  - 178s - loss: 0.6489 - acc: 0.7935 - val_loss: 1.1271 - val_acc: 0.7076
# Epoch 41/50
#  - 176s - loss: 0.6428 - acc: 0.7937 - val_loss: 0.8696 - val_acc: 0.7666
# Epoch 42/50
#  - 179s - loss: 0.6584 - acc: 0.7904 - val_loss: 0.7691 - val_acc: 0.7702
# Epoch 43/50
#  - 186s - loss: 0.6605 - acc: 0.7898 - val_loss: 0.7217 - val_acc: 0.7875
# Epoch 44/50
#  - 187s - loss: 0.6533 - acc: 0.7910 - val_loss: 0.6823 - val_acc: 0.7841
# Epoch 45/50
#  - 186s - loss: 0.6606 - acc: 0.7887 - val_loss: 0.8053 - val_acc: 0.7698
# Epoch 46/50
#  - 188s - loss: 0.6722 - acc: 0.7875 - val_loss: 0.7727 - val_acc: 0.7738
# Epoch 47/50
#  - 180s - loss: 0.6730 - acc: 0.7869 - val_loss: 0.7037 - val_acc: 0.7952
# Epoch 48/50
#  - 177s - loss: 0.6705 - acc: 0.7870 - val_loss: 0.8271 - val_acc: 0.7731
# Epoch 49/50
#  - 176s - loss: 0.6838 - acc: 0.7834 - val_loss: 0.7089 - val_acc: 0.7980
# Epoch 50/50
#  - 176s - loss: 0.6858 - acc: 0.7850 - val_loss: 0.8656 - val_acc: 0.7662

# %%
trainer.display('acc', 'val_acc')

# %%
trainer.display('loss', 'val_loss')
