# %% [markdown]
# ## 作業
#
# 1. 試改變監控 Validation Accuracy 並比較結果
# 2. 調整 Early Stopping 的等待次數至 10 和 25 並比較結果

# %% [markdown]
# ## 參考資料
#
# [keras 的 EarlyStopping callbacks 的使用与技巧](https://blog.csdn.net/silent56_th/article/details/72845912)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from keras import backend
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.models import Model
from keras.layers import Input, Dense, BatchNormalization
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
tf.logging.set_verbosity(tf.logging.ERROR)

# %% [markdown]
# ## 準備資料

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
def normalize_cifar10_data(x, y):
    x = x.reshape((len(x), -1)) / 255.
    y = np_utils.to_categorical(y, num_classes=10)
    return x, y

def normalize_result(x, y):
    print('x.shape:', x.shape)
    print('y.shape:', y.shape)

# %%
print('Before normalization:')
normalize_result(X_train, y_train)
# Out:
# Before normalization:
# x.shape: (50000, 32, 32, 3)
# y.shape: (50000, 1)

# %%
print('After normalization:')
X_train, y_train = normalize_cifar10_data(X_train, y_train)
X_test, y_test = normalize_cifar10_data(X_test, y_test)
normalize_result(X_train, y_train)
# Out:
# After normalization:
# x.shape: (50000, 3072)
# y.shape: (50000, 10)

# %% [markdown]
# ## 定義函數

# %%
default_early_stopping_param = {'monitor': 'val_loss', 'patience': 5, 'verbose': 1}

class Trainer:

    def __init__(self, X_train, y_train, X_test, y_test, early_stopping_param, neuron_numbers=(512, 256, 128,),
                 epochs=50, batch_size=1024, momentum=0.95, learning_rate=1e-3):
        self.X_test = X_test
        self.y_test = y_test
        self.X_train = X_train
        self.y_train = y_train
        self.epochs = epochs
        self.batch_size = batch_size
        self.momentum = momentum
        self.learning_rate = learning_rate
        self.neuron_numbers = neuron_numbers
        self.early_stopping_param = early_stopping_param
        self._model = None
        self._score = None
        self._history = None

    @property
    def optimizer(self):
        return SGD(lr=self.learning_rate, momentum=self.momentum, nesterov=True)

    @property
    def callbacks(self):
        return [EarlyStopping(**self.early_stopping_param)]

    @property
    def validation_data(self):
        return (self.X_test, self.y_test,)

    def run(self):
        return self._clear()._build()._launch()

    def _clear(self):
        backend.clear_session()
        self._model = None
        return self

    def _build(self):
        main_input = hidden_input = Input(shape=self.X_train.shape[-1:], name='main_input')
        for i, neuron_number in enumerate(self.neuron_numbers):
            hidden_input = Dense(units=neuron_number, activation='relu', name=f'hidden_layer{i}')(hidden_input)
            hidden_input = BatchNormalization()(hidden_input)
        main_output = Dense(units=self.y_train.shape[-1], activation='softmax', name='main_output')(hidden_input)
        self._model = Model(inputs=[main_input], outputs=[main_output])
        self._model.compile(optimizer=self.optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
        return self

    def _launch(self):
        print('Experiment with early stopping param: {}'.format(self.early_stopping_param))
        self._model.summary()
        self._history = self._model.fit(
            self.X_train, self.y_train, epochs=self.epochs, batch_size=self.batch_size,
            validation_data=self.validation_data, callbacks=self.callbacks, shuffle=True, verbose=2)
        return self

    def evaluate(self):
        self._score = dict(zip(('val_loss', 'val_acc',), self._model.evaluate(self.X_test, self.y_test)))
        return self

    def display(self, train_name, val_name):
        plt.figure(figsize=(8, 6,))
        plt.plot(self._history.history[train_name])
        plt.plot(self._history.history[val_name])
        plt.xlabel('Epoch')
        plt.ylabel(train_name)
        plt.title('Train History')
        plt.legend(['train', 'validation'], loc='upper left')
        plt.show()

# %% [markdown]
# ## 以監控驗證集準確度觀看學習曲線的走勢

# %%
# 設定超參數
early_stopping_param = {**default_early_stopping_param, 'monitor': 'val_acc'}

# %%
trainer = Trainer(X_train, y_train, X_test, y_test, early_stopping_param).run()
# Out:
# Experiment with early stopping param: {'monitor': 'val_acc', 'patience': 5, 'verbose': 1}
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 3072)              0
# _________________________________________________________________
# hidden_layer0 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# main_output (Dense)          (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#  - 9s - loss: 2.2218 - acc: 0.2714 - val_loss: 2.0665 - val_acc: 0.3277
# Epoch 2/50
#  - 9s - loss: 1.7411 - acc: 0.3921 - val_loss: 1.8510 - val_acc: 0.3648
# Epoch 3/50
#  - 9s - loss: 1.6171 - acc: 0.4325 - val_loss: 1.6875 - val_acc: 0.4168
# Epoch 4/50
#  - 8s - loss: 1.5434 - acc: 0.4608 - val_loss: 1.6472 - val_acc: 0.4214
# Epoch 5/50
#  - 8s - loss: 1.4862 - acc: 0.4782 - val_loss: 1.6171 - val_acc: 0.4353
# Epoch 6/50
#  - 9s - loss: 1.4422 - acc: 0.4959 - val_loss: 1.5871 - val_acc: 0.4487
# Epoch 7/50
#  - 9s - loss: 1.4026 - acc: 0.5092 - val_loss: 1.5570 - val_acc: 0.4572
# Epoch 8/50
#  - 9s - loss: 1.3646 - acc: 0.5227 - val_loss: 1.5339 - val_acc: 0.4621
# Epoch 9/50
#  - 8s - loss: 1.3328 - acc: 0.5357 - val_loss: 1.5116 - val_acc: 0.4718
# Epoch 10/50
#  - 9s - loss: 1.3020 - acc: 0.5462 - val_loss: 1.5156 - val_acc: 0.4676
# Epoch 11/50
#  - 10s - loss: 1.2743 - acc: 0.5581 - val_loss: 1.5209 - val_acc: 0.4675
# Epoch 12/50
#  - 10s - loss: 1.2460 - acc: 0.5673 - val_loss: 1.4951 - val_acc: 0.4789
# Epoch 13/50
#  - 9s - loss: 1.2210 - acc: 0.5785 - val_loss: 1.4822 - val_acc: 0.4811
# Epoch 14/50
#  - 9s - loss: 1.1941 - acc: 0.5883 - val_loss: 1.4902 - val_acc: 0.4829
# Epoch 15/50
#  - 9s - loss: 1.1686 - acc: 0.5979 - val_loss: 1.4814 - val_acc: 0.4826
# Epoch 16/50
#  - 9s - loss: 1.1449 - acc: 0.6069 - val_loss: 1.4769 - val_acc: 0.4853
# Epoch 17/50
#  - 9s - loss: 1.1220 - acc: 0.6168 - val_loss: 1.4784 - val_acc: 0.4883
# Epoch 18/50
#  - 9s - loss: 1.1018 - acc: 0.6231 - val_loss: 1.4756 - val_acc: 0.4846
# Epoch 19/50
#  - 9s - loss: 1.0769 - acc: 0.6302 - val_loss: 1.4698 - val_acc: 0.4941
# Epoch 20/50
#  - 9s - loss: 1.0555 - acc: 0.6424 - val_loss: 1.4715 - val_acc: 0.4869
# Epoch 21/50
#  - 9s - loss: 1.0325 - acc: 0.6498 - val_loss: 1.4659 - val_acc: 0.4946
# Epoch 22/50
#  - 9s - loss: 1.0119 - acc: 0.6566 - val_loss: 1.4641 - val_acc: 0.4906
# Epoch 23/50
#  - 9s - loss: 0.9914 - acc: 0.6652 - val_loss: 1.4640 - val_acc: 0.4897
# Epoch 24/50
#  - 9s - loss: 0.9714 - acc: 0.6736 - val_loss: 1.4610 - val_acc: 0.4972
# Epoch 25/50
#  - 9s - loss: 0.9495 - acc: 0.6825 - val_loss: 1.4732 - val_acc: 0.4922
# Epoch 26/50
#  - 9s - loss: 0.9300 - acc: 0.6890 - val_loss: 1.4840 - val_acc: 0.4922
# Epoch 27/50
#  - 9s - loss: 0.9094 - acc: 0.6984 - val_loss: 1.4822 - val_acc: 0.4925
# Epoch 28/50
#  - 9s - loss: 0.8885 - acc: 0.7052 - val_loss: 1.4756 - val_acc: 0.4923
# Epoch 29/50
#  - 9s - loss: 0.8690 - acc: 0.7120 - val_loss: 1.4967 - val_acc: 0.4904
# Epoch 00029: early stopping

# %%
trainer.display('acc', 'val_acc')

# %%
trainer.display('loss', 'val_loss')

# %% [markdown]
# ## 以調升至 10 的等待次數觀看學習曲線的走勢

# %%
# 設定超參數
early_stopping_param = {**default_early_stopping_param, 'patience': 10}

# %%
trainer = Trainer(X_train, y_train, X_test, y_test, early_stopping_param).run()
# Out:
# Experiment with early stopping param: {'monitor': 'val_loss', 'patience': 10, 'verbose': 1}
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 3072)              0
# _________________________________________________________________
# hidden_layer0 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# main_output (Dense)          (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#  - 10s - loss: 2.2261 - acc: 0.2700 - val_loss: 2.0653 - val_acc: 0.3261
# Epoch 2/50
#  - 9s - loss: 1.7542 - acc: 0.3889 - val_loss: 1.8123 - val_acc: 0.3753
# Epoch 3/50
#  - 9s - loss: 1.6246 - acc: 0.4328 - val_loss: 1.6918 - val_acc: 0.4050
# Epoch 4/50
#  - 9s - loss: 1.5519 - acc: 0.4573 - val_loss: 1.6373 - val_acc: 0.4268
# Epoch 5/50
#  - 9s - loss: 1.4947 - acc: 0.4766 - val_loss: 1.6001 - val_acc: 0.4358
# Epoch 6/50
#  - 9s - loss: 1.4492 - acc: 0.4950 - val_loss: 1.5665 - val_acc: 0.4494
# Epoch 7/50
#  - 9s - loss: 1.4079 - acc: 0.5097 - val_loss: 1.5551 - val_acc: 0.4571
# Epoch 8/50
#  - 9s - loss: 1.3739 - acc: 0.5213 - val_loss: 1.5499 - val_acc: 0.4606
# Epoch 9/50
#  - 9s - loss: 1.3404 - acc: 0.5327 - val_loss: 1.5207 - val_acc: 0.4660
# Epoch 10/50
#  - 9s - loss: 1.3091 - acc: 0.5459 - val_loss: 1.5084 - val_acc: 0.4774
# Epoch 11/50
#  - 9s - loss: 1.2801 - acc: 0.5561 - val_loss: 1.5070 - val_acc: 0.4716
# Epoch 12/50
#  - 9s - loss: 1.2547 - acc: 0.5638 - val_loss: 1.5038 - val_acc: 0.4734
# Epoch 13/50
#  - 9s - loss: 1.2306 - acc: 0.5743 - val_loss: 1.4825 - val_acc: 0.4776
# Epoch 14/50
#  - 9s - loss: 1.2032 - acc: 0.5841 - val_loss: 1.4758 - val_acc: 0.4845
# Epoch 15/50
#  - 9s - loss: 1.1802 - acc: 0.5925 - val_loss: 1.4822 - val_acc: 0.4811
# Epoch 16/50
#  - 9s - loss: 1.1574 - acc: 0.6004 - val_loss: 1.4774 - val_acc: 0.4816
# Epoch 17/50
#  - 9s - loss: 1.1327 - acc: 0.6096 - val_loss: 1.4628 - val_acc: 0.4833
# Epoch 18/50
#  - 9s - loss: 1.1117 - acc: 0.6186 - val_loss: 1.4719 - val_acc: 0.4894
# Epoch 19/50
#  - 9s - loss: 1.0874 - acc: 0.6284 - val_loss: 1.4714 - val_acc: 0.4875
# Epoch 20/50
#  - 9s - loss: 1.0657 - acc: 0.6359 - val_loss: 1.4708 - val_acc: 0.4874
# Epoch 21/50
#  - 9s - loss: 1.0456 - acc: 0.6447 - val_loss: 1.4628 - val_acc: 0.4903
# Epoch 22/50
#  - 9s - loss: 1.0251 - acc: 0.6524 - val_loss: 1.4573 - val_acc: 0.4906
# Epoch 23/50
#  - 9s - loss: 1.0037 - acc: 0.6596 - val_loss: 1.4642 - val_acc: 0.4925
# Epoch 24/50
#  - 9s - loss: 0.9828 - acc: 0.6698 - val_loss: 1.4649 - val_acc: 0.4966
# Epoch 25/50
#  - 9s - loss: 0.9609 - acc: 0.6770 - val_loss: 1.4653 - val_acc: 0.4917
# Epoch 26/50
#  - 9s - loss: 0.9393 - acc: 0.6862 - val_loss: 1.4714 - val_acc: 0.4913
# Epoch 27/50
#  - 9s - loss: 0.9193 - acc: 0.6930 - val_loss: 1.4661 - val_acc: 0.4959
# Epoch 28/50
#  - 9s - loss: 0.8995 - acc: 0.7019 - val_loss: 1.4873 - val_acc: 0.4941
# Epoch 29/50
#  - 9s - loss: 0.8787 - acc: 0.7100 - val_loss: 1.5001 - val_acc: 0.4935
# Epoch 30/50
#  - 9s - loss: 0.8582 - acc: 0.7179 - val_loss: 1.4899 - val_acc: 0.4968
# Epoch 31/50
#  - 9s - loss: 0.8367 - acc: 0.7260 - val_loss: 1.4962 - val_acc: 0.4945
# Epoch 32/50
#  - 9s - loss: 0.8188 - acc: 0.7331 - val_loss: 1.5004 - val_acc: 0.4943
# Epoch 00032: early stopping

# %%
trainer.display('acc', 'val_acc')

# %%
trainer.display('loss', 'val_loss')

# %% [markdown]
# ## 以調升至 25 的等待次數觀看學習曲線的走勢

# %%
# 設定超參數
early_stopping_param = {**default_early_stopping_param, 'patience': 25}

# %%
trainer = Trainer(X_train, y_train, X_test, y_test, early_stopping_param).run()
# Out:
# Experiment with early stopping param: {'monitor': 'val_loss', 'patience': 25, 'verbose': 1}
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 3072)              0
# _________________________________________________________________
# hidden_layer0 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# main_output (Dense)          (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#  - 10s - loss: 2.2011 - acc: 0.2711 - val_loss: 2.0393 - val_acc: 0.3197
# Epoch 2/50
#  - 9s - loss: 1.7580 - acc: 0.3861 - val_loss: 1.7913 - val_acc: 0.3788
# Epoch 3/50
#  - 9s - loss: 1.6295 - acc: 0.4291 - val_loss: 1.6956 - val_acc: 0.4088
# Epoch 4/50
#  - 9s - loss: 1.5522 - acc: 0.4566 - val_loss: 1.6286 - val_acc: 0.4277
# Epoch 5/50
#  - 9s - loss: 1.4953 - acc: 0.4781 - val_loss: 1.5995 - val_acc: 0.4398
# Epoch 6/50
#  - 9s - loss: 1.4491 - acc: 0.4949 - val_loss: 1.5629 - val_acc: 0.4477
# Epoch 7/50
#  - 9s - loss: 1.4102 - acc: 0.5090 - val_loss: 1.5472 - val_acc: 0.4572
# Epoch 8/50
#  - 9s - loss: 1.3737 - acc: 0.5227 - val_loss: 1.5266 - val_acc: 0.4633
# Epoch 9/50
#  - 9s - loss: 1.3402 - acc: 0.5346 - val_loss: 1.5195 - val_acc: 0.4698
# Epoch 10/50
#  - 9s - loss: 1.3120 - acc: 0.5456 - val_loss: 1.5033 - val_acc: 0.4742
# Epoch 11/50
#  - 9s - loss: 1.2834 - acc: 0.5535 - val_loss: 1.4968 - val_acc: 0.4733
# Epoch 12/50
#  - 9s - loss: 1.2553 - acc: 0.5659 - val_loss: 1.4971 - val_acc: 0.4753
# Epoch 13/50
#  - 9s - loss: 1.2295 - acc: 0.5741 - val_loss: 1.4782 - val_acc: 0.4807
# Epoch 14/50
#  - 9s - loss: 1.2043 - acc: 0.5840 - val_loss: 1.4786 - val_acc: 0.4798
# Epoch 15/50
#  - 9s - loss: 1.1802 - acc: 0.5938 - val_loss: 1.4709 - val_acc: 0.4798
# Epoch 16/50
#  - 9s - loss: 1.1558 - acc: 0.6034 - val_loss: 1.4690 - val_acc: 0.4823
# Epoch 17/50
#  - 9s - loss: 1.1331 - acc: 0.6104 - val_loss: 1.4720 - val_acc: 0.4814
# Epoch 18/50
#  - 9s - loss: 1.1131 - acc: 0.6180 - val_loss: 1.4718 - val_acc: 0.4834
# Epoch 19/50
#  - 9s - loss: 1.0891 - acc: 0.6270 - val_loss: 1.4629 - val_acc: 0.4850
# Epoch 20/50
#  - 9s - loss: 1.0672 - acc: 0.6346 - val_loss: 1.4710 - val_acc: 0.4832
# Epoch 21/50
#  - 9s - loss: 1.0453 - acc: 0.6440 - val_loss: 1.4660 - val_acc: 0.4839
# Epoch 22/50
#  - 9s - loss: 1.0240 - acc: 0.6511 - val_loss: 1.4611 - val_acc: 0.4904
# Epoch 23/50
#  - 9s - loss: 1.0029 - acc: 0.6598 - val_loss: 1.4641 - val_acc: 0.4914
# Epoch 24/50
#  - 9s - loss: 0.9815 - acc: 0.6678 - val_loss: 1.4667 - val_acc: 0.4932
# Epoch 25/50
#  - 9s - loss: 0.9610 - acc: 0.6744 - val_loss: 1.4753 - val_acc: 0.4879
# Epoch 26/50
#  - 9s - loss: 0.9416 - acc: 0.6847 - val_loss: 1.4860 - val_acc: 0.4856
# Epoch 27/50
#  - 9s - loss: 0.9206 - acc: 0.6916 - val_loss: 1.4888 - val_acc: 0.4863
# Epoch 28/50
#  - 9s - loss: 0.9018 - acc: 0.6992 - val_loss: 1.4951 - val_acc: 0.4933
# Epoch 29/50
#  - 9s - loss: 0.8812 - acc: 0.7061 - val_loss: 1.4928 - val_acc: 0.4914
# Epoch 30/50
#  - 9s - loss: 0.8628 - acc: 0.7153 - val_loss: 1.4969 - val_acc: 0.4892
# Epoch 31/50
#  - 9s - loss: 0.8411 - acc: 0.7229 - val_loss: 1.5088 - val_acc: 0.4888
# Epoch 32/50
#  - 9s - loss: 0.8201 - acc: 0.7309 - val_loss: 1.5049 - val_acc: 0.4897
# Epoch 33/50
#  - 9s - loss: 0.8004 - acc: 0.7387 - val_loss: 1.5314 - val_acc: 0.4899
# Epoch 34/50
#  - 9s - loss: 0.7840 - acc: 0.7439 - val_loss: 1.5092 - val_acc: 0.4937
# Epoch 35/50
#  - 9s - loss: 0.7648 - acc: 0.7541 - val_loss: 1.5328 - val_acc: 0.4898
# Epoch 36/50
#  - 9s - loss: 0.7442 - acc: 0.7607 - val_loss: 1.5384 - val_acc: 0.4855
# Epoch 37/50
#  - 9s - loss: 0.7286 - acc: 0.7669 - val_loss: 1.5473 - val_acc: 0.4879
# Epoch 38/50
#  - 9s - loss: 0.7094 - acc: 0.7763 - val_loss: 1.5788 - val_acc: 0.4829
# Epoch 39/50
#  - 9s - loss: 0.6906 - acc: 0.7825 - val_loss: 1.5685 - val_acc: 0.4907
# Epoch 40/50
#  - 9s - loss: 0.6730 - acc: 0.7908 - val_loss: 1.5694 - val_acc: 0.4927
# Epoch 41/50
#  - 10s - loss: 0.6543 - acc: 0.7976 - val_loss: 1.5961 - val_acc: 0.4867
# Epoch 42/50
#  - 9s - loss: 0.6367 - acc: 0.8039 - val_loss: 1.6152 - val_acc: 0.4841
# Epoch 43/50
#  - 9s - loss: 0.6190 - acc: 0.8116 - val_loss: 1.6135 - val_acc: 0.4850
# Epoch 44/50
#  - 9s - loss: 0.5999 - acc: 0.8191 - val_loss: 1.6040 - val_acc: 0.4891
# Epoch 45/50
#  - 9s - loss: 0.5848 - acc: 0.8259 - val_loss: 1.6582 - val_acc: 0.4848
# Epoch 46/50
#  - 9s - loss: 0.5663 - acc: 0.8340 - val_loss: 1.6671 - val_acc: 0.4817
# Epoch 47/50
#  - 9s - loss: 0.5513 - acc: 0.8391 - val_loss: 1.6606 - val_acc: 0.4805
# Epoch 00047: early stopping

# %%
trainer.display('acc', 'val_acc')

# %%
trainer.display('loss', 'val_loss')
