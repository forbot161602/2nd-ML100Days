# %% [markdown]
# ## 作業
#
# 1. 試改變監控 Validation Accuracy 並比較結果
# 2. 調整 Early Stopping 的等待次數至 10 和 25 並比較結果

# %% [markdown]
# ## 參考資料
#
# [keras 的 EarlyStopping callbacks 的使用与技巧](https://blog.csdn.net/silent56_th/article/details/72845912)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from keras import backend
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.models import Model
from keras.layers import Input, Dense, BatchNormalization
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
tf.logging.set_verbosity(tf.logging.ERROR)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 準備資料

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
def normalize_cifar10_data(x, y):
    x = x.reshape((len(x), -1)) / 255.
    y = np_utils.to_categorical(y, num_classes=10)
    return x, y

def normalize_result(x, y):
    print('x.shape:', x.shape)
    print('y.shape:', y.shape)

# %%
print('Before normalization:')
normalize_result(X_train, y_train)
# Out:
# Before normalization:
# x.shape: (50000, 32, 32, 3)
# y.shape: (50000, 1)

# %%
print('After normalization:')
X_train, y_train = normalize_cifar10_data(X_train, y_train)
X_test, y_test = normalize_cifar10_data(X_test, y_test)
normalize_result(X_train, y_train)
# Out:
# After normalization:
# x.shape: (50000, 3072)
# y.shape: (50000, 10)

# %% [markdown]
# ## 定義函數

# %%
default_early_stopping_param = {'monitor': 'val_loss', 'patience': 5, 'verbose': 1}

def train_model(X_train, y_train, X_test, y_test, early_stopping_param, neuron_numbers=(512, 256, 128,),
                epochs=50, batch_size=256, momentum=0.95, learning_rate=1e-3):
    print('Experiment with early stopping param: {}'.format(early_stopping_param))
    backend.clear_session() # 清掉舊的 Graph
    model = build_model(X_train, X_train.shape[-1:], 10, neuron_numbers)
    model.summary()
    model.compile(optimizer=SGD(lr=learning_rate, momentum=momentum, nesterov=True),
                  loss='categorical_crossentropy', metrics=['accuracy'])
    return model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_test, y_test,),
                     callbacks=[EarlyStopping(**early_stopping_param)], shuffle=True, verbose=2)

def build_model(x, input_shape, output_units, neuron_numbers):
    main_input = hidden_input = Input(shape=input_shape, name='main_input')
    for i, neuron_number in enumerate(neuron_numbers):
        hidden_input = Dense(units=neuron_number, activation='relu', name=f'hidden_layer{i}')(hidden_input)
        hidden_input = BatchNormalization()(hidden_input)
    main_output = Dense(units=output_units, activation='softmax', name='main_output')(hidden_input)
    return Model(inputs=[main_input], outputs=[main_output])

def show_train_history(train_history, train_name, val_name):
    plt.figure(figsize=(8, 6,))
    plt.plot(train_history.history[train_name])
    plt.plot(train_history.history[val_name])
    plt.xlabel('Epoch')
    plt.ylabel(train_name)
    plt.title('Train History')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

# %% [markdown]
# ## 以監控驗證集準確度觀看學習曲線的走勢

# %%
## 設定超參數
early_stopping_param = {**default_early_stopping_param, 'monitor': 'val_acc'}

# %%
train_history = train_model(X_train, y_train, X_test, y_test, early_stopping_param)
# Out:
# Experiment with early stopping param: {'monitor': 'val_acc', 'patience': 5, 'verbose': 1}
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 3072)              0
# _________________________________________________________________
# hidden_layer0 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# main_output (Dense)          (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#  - 13s - loss: 1.8643 - acc: 0.3644 - val_loss: 1.7189 - val_acc: 0.4016
# Epoch 2/50
#  - 12s - loss: 1.5372 - acc: 0.4623 - val_loss: 1.7308 - val_acc: 0.4020
# Epoch 3/50
#  - 12s - loss: 1.4350 - acc: 0.4971 - val_loss: 1.5425 - val_acc: 0.4601
# Epoch 4/50
#  - 12s - loss: 1.3639 - acc: 0.5235 - val_loss: 1.6693 - val_acc: 0.4228
# Epoch 5/50
#  - 12s - loss: 1.3035 - acc: 0.5455 - val_loss: 1.5144 - val_acc: 0.4698
# Epoch 6/50
#  - 12s - loss: 1.2559 - acc: 0.5638 - val_loss: 1.4673 - val_acc: 0.4807
# Epoch 7/50
#  - 12s - loss: 1.2082 - acc: 0.5792 - val_loss: 1.4399 - val_acc: 0.4998
# Epoch 8/50
#  - 12s - loss: 1.1663 - acc: 0.5943 - val_loss: 1.4730 - val_acc: 0.4801
# Epoch 9/50
#  - 12s - loss: 1.1249 - acc: 0.6084 - val_loss: 1.5142 - val_acc: 0.4799
# Epoch 10/50
#  - 12s - loss: 1.0823 - acc: 0.6244 - val_loss: 1.4906 - val_acc: 0.4746
# Epoch 11/50
#  - 12s - loss: 1.0485 - acc: 0.6338 - val_loss: 1.4703 - val_acc: 0.4905
# Epoch 12/50
#  - 12s - loss: 1.0130 - acc: 0.6484 - val_loss: 1.4935 - val_acc: 0.4821
# Epoch 00012: early stopping

# %%
show_train_history(train_history, 'acc', 'val_acc')

# %%
show_train_history(train_history, 'loss', 'val_loss')

# %% [markdown]
# ## 以調升至 10 的等待次數觀看學習曲線的走勢

# %%
## 設定超參數
early_stopping_param = {**default_early_stopping_param, 'patience': 10}

# %%
train_history = train_model(X_train, y_train, X_test, y_test, early_stopping_param)
# Out:
# Experiment with early stopping param: {'monitor': 'val_loss', 'patience': 10, 'verbose': 1}
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 3072)              0
# _________________________________________________________________
# hidden_layer0 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# main_output (Dense)          (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#  - 13s - loss: 1.8642 - acc: 0.3612 - val_loss: 1.7777 - val_acc: 0.3876
# Epoch 2/50
#  - 12s - loss: 1.5499 - acc: 0.4548 - val_loss: 1.6110 - val_acc: 0.4259
# Epoch 3/50
#  - 12s - loss: 1.4454 - acc: 0.4898 - val_loss: 1.5582 - val_acc: 0.4471
# Epoch 4/50
#  - 12s - loss: 1.3748 - acc: 0.5159 - val_loss: 1.5067 - val_acc: 0.4731
# Epoch 5/50
#  - 13s - loss: 1.3129 - acc: 0.5398 - val_loss: 1.5262 - val_acc: 0.4646
# Epoch 6/50
#  - 14s - loss: 1.2626 - acc: 0.5579 - val_loss: 1.5687 - val_acc: 0.4538
# Epoch 7/50
#  - 12s - loss: 1.2147 - acc: 0.5748 - val_loss: 1.5410 - val_acc: 0.4493
# Epoch 8/50
#  - 12s - loss: 1.1733 - acc: 0.5891 - val_loss: 1.5351 - val_acc: 0.4638
# Epoch 9/50
#  - 12s - loss: 1.1320 - acc: 0.6051 - val_loss: 1.4633 - val_acc: 0.4854
# Epoch 10/50
#  - 12s - loss: 1.0909 - acc: 0.6175 - val_loss: 1.5028 - val_acc: 0.4775
# Epoch 11/50
#  - 11s - loss: 1.0534 - acc: 0.6315 - val_loss: 1.4539 - val_acc: 0.4883
# Epoch 12/50
#  - 11s - loss: 1.0171 - acc: 0.6461 - val_loss: 1.5407 - val_acc: 0.4691
# Epoch 13/50
#  - 12s - loss: 0.9812 - acc: 0.6612 - val_loss: 1.5188 - val_acc: 0.4805
# Epoch 14/50
#  - 12s - loss: 0.9477 - acc: 0.6732 - val_loss: 1.5261 - val_acc: 0.4744
# Epoch 15/50
#  - 12s - loss: 0.9110 - acc: 0.6857 - val_loss: 1.5919 - val_acc: 0.4718
# Epoch 16/50
#  - 13s - loss: 0.8802 - acc: 0.6968 - val_loss: 1.5421 - val_acc: 0.4777
# Epoch 17/50
#  - 12s - loss: 0.8459 - acc: 0.7095 - val_loss: 1.5771 - val_acc: 0.4791
# Epoch 18/50
#  - 12s - loss: 0.8147 - acc: 0.7205 - val_loss: 1.5823 - val_acc: 0.4752
# Epoch 19/50
#  - 12s - loss: 0.7817 - acc: 0.7324 - val_loss: 1.5875 - val_acc: 0.4753
# Epoch 20/50
#  - 12s - loss: 0.7480 - acc: 0.7461 - val_loss: 1.6445 - val_acc: 0.4731
# Epoch 21/50
#  - 12s - loss: 0.7227 - acc: 0.7525 - val_loss: 1.6068 - val_acc: 0.4780
# Epoch 00021: early stopping

# %%
show_train_history(train_history, 'acc', 'val_acc')

# %%
show_train_history(train_history, 'loss', 'val_loss')

# %% [markdown]
# ## 以調升至 25 的等待次數觀看學習曲線的走勢

# %%
## 設定超參數
early_stopping_param = {**default_early_stopping_param, 'patience': 25}

# %%
train_history = train_model(X_train, y_train, X_test, y_test, early_stopping_param)
# Out:
# Experiment with early stopping param: {'monitor': 'val_loss', 'patience': 25, 'verbose': 1}
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 3072)              0
# _________________________________________________________________
# hidden_layer0 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# main_output (Dense)          (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#  - 13s - loss: 1.8697 - acc: 0.3609 - val_loss: 1.7585 - val_acc: 0.3977
# Epoch 2/50
#  - 12s - loss: 1.5473 - acc: 0.4565 - val_loss: 1.5920 - val_acc: 0.4409
# Epoch 3/50
#  - 12s - loss: 1.4443 - acc: 0.4929 - val_loss: 1.5829 - val_acc: 0.4377
# Epoch 4/50
#  - 12s - loss: 1.3722 - acc: 0.5185 - val_loss: 1.5860 - val_acc: 0.4427
# Epoch 5/50
#  - 12s - loss: 1.3123 - acc: 0.5391 - val_loss: 1.5119 - val_acc: 0.4614
# Epoch 6/50
#  - 12s - loss: 1.2572 - acc: 0.5594 - val_loss: 1.5900 - val_acc: 0.4479
# Epoch 7/50
#  - 12s - loss: 1.2106 - acc: 0.5764 - val_loss: 1.4939 - val_acc: 0.4756
# Epoch 8/50
#  - 12s - loss: 1.1714 - acc: 0.5896 - val_loss: 1.4852 - val_acc: 0.4744
# Epoch 9/50
#  - 13s - loss: 1.1279 - acc: 0.6079 - val_loss: 1.5089 - val_acc: 0.4698
# Epoch 10/50
#  - 12s - loss: 1.0863 - acc: 0.6219 - val_loss: 1.4721 - val_acc: 0.4845
# Epoch 11/50
#  - 13s - loss: 1.0479 - acc: 0.6359 - val_loss: 1.5013 - val_acc: 0.4830
# Epoch 12/50
#  - 12s - loss: 1.0117 - acc: 0.6494 - val_loss: 1.5658 - val_acc: 0.4732
# Epoch 13/50
#  - 12s - loss: 0.9745 - acc: 0.6648 - val_loss: 1.4925 - val_acc: 0.4913
# Epoch 14/50
#  - 12s - loss: 0.9418 - acc: 0.6742 - val_loss: 1.5496 - val_acc: 0.4731
# Epoch 15/50
#  - 12s - loss: 0.9094 - acc: 0.6863 - val_loss: 1.5841 - val_acc: 0.4634
# Epoch 16/50
#  - 13s - loss: 0.8741 - acc: 0.6997 - val_loss: 1.5549 - val_acc: 0.4806
# Epoch 17/50
#  - 13s - loss: 0.8439 - acc: 0.7107 - val_loss: 1.5665 - val_acc: 0.4783
# Epoch 18/50
#  - 12s - loss: 0.8133 - acc: 0.7231 - val_loss: 1.6150 - val_acc: 0.4756
# Epoch 19/50
#  - 13s - loss: 0.7810 - acc: 0.7356 - val_loss: 1.5964 - val_acc: 0.4807
# Epoch 20/50
#  - 12s - loss: 0.7472 - acc: 0.7446 - val_loss: 1.6301 - val_acc: 0.4627
# Epoch 21/50
#  - 12s - loss: 0.7216 - acc: 0.7539 - val_loss: 1.6053 - val_acc: 0.4841
# Epoch 22/50
#  - 12s - loss: 0.6830 - acc: 0.7687 - val_loss: 1.6403 - val_acc: 0.4812
# Epoch 23/50
#  - 12s - loss: 0.6564 - acc: 0.7790 - val_loss: 1.7214 - val_acc: 0.4699
# Epoch 24/50
#  - 12s - loss: 0.6303 - acc: 0.7878 - val_loss: 1.7251 - val_acc: 0.4767
# Epoch 25/50
#  - 12s - loss: 0.6026 - acc: 0.7989 - val_loss: 1.8503 - val_acc: 0.4487
# Epoch 26/50
#  - 12s - loss: 0.5776 - acc: 0.8086 - val_loss: 1.7483 - val_acc: 0.4767
# Epoch 27/50
#  - 12s - loss: 0.5516 - acc: 0.8194 - val_loss: 1.7729 - val_acc: 0.4685
# Epoch 28/50
#  - 12s - loss: 0.5265 - acc: 0.8271 - val_loss: 1.9226 - val_acc: 0.4545
# Epoch 29/50
#  - 12s - loss: 0.4993 - acc: 0.8361 - val_loss: 1.9241 - val_acc: 0.4661
# Epoch 30/50
#  - 12s - loss: 0.4712 - acc: 0.8467 - val_loss: 1.9103 - val_acc: 0.4751
# Epoch 31/50
#  - 12s - loss: 0.4512 - acc: 0.8570 - val_loss: 1.8883 - val_acc: 0.4828
# Epoch 32/50
#  - 12s - loss: 0.4296 - acc: 0.8622 - val_loss: 2.0117 - val_acc: 0.4598
# Epoch 33/50
#  - 12s - loss: 0.4071 - acc: 0.8704 - val_loss: 2.1225 - val_acc: 0.4559
# Epoch 34/50
#  - 12s - loss: 0.3889 - acc: 0.8777 - val_loss: 2.1691 - val_acc: 0.4537
# Epoch 35/50
#  - 12s - loss: 0.3730 - acc: 0.8812 - val_loss: 2.1754 - val_acc: 0.4546
# Epoch 00035: early stopping

# %%
show_train_history(train_history, 'acc', 'val_acc')

# %%
show_train_history(train_history, 'loss', 'val_loss')
