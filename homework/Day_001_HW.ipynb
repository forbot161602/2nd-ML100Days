# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# ## 參考資料
#
# #### Data Scientist、Data Analyst、Data Engineer 的區別是什麼？
#
# [Data Scientist vs Data Engineer](https://www.datacamp.com/community/blog/data-scientist-vs-data-engineer)
#
# #### 資料科學家需要目標的領域知識
#
# [Why Data Scientists Must Focus on Developing Product Sense](https://www.kdnuggets.com/2018/04/data-scientists-product-sense.html)
#
# #### 想當資料科學家 : 三思而後行
#
# [Why so many data scientists are leaving their jobs](https://www.kdnuggets.com/2018/04/why-data-scientists-leaving-jobs.html)

# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估
#
# 答：選擇資料集網址 https://www.kaggle.com/lava18/google-play-store-apps
#
# 1. 可以從幾個條件歸納出市場目前對於某些應用程式的偏好程度
#
# 2. 資料從 Google Play 網頁上爬下來的
#
# 3. 欄位有應用程式名稱、分類、評價、大小、價錢、安卓版本等等，連續或間斷數據皆有。
#
# 4. 可能以應用程式分類為前提，入參名稱、價錢、類型、安卓版本、更新頻率等來推估評價或安裝次數等數據。

# %% [markdown]
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 答：
#
# 1. 收集現有資料，嘗試找出各種造成業績提升的變因，藉由改變有關這些變因的策略，使得收益成長。
#
# 2. 從車隊每次載客的數據而來，例如司機的年齡、車種、談吐等，這些資料可在面試、抽查等能得知，或是載客地點、目的地、時間、距離、價錢等，這些資料可在每輪載客時量測並記錄，各種資料或多或少都有可能對業績造成影響。
#
# 3. 年齡、時間、距離、價錢等為範圍內的數值資料，而車種、談吐等為類別資料，另外地點、目的地等為平面上的連續數值資料。
#
# 4. 粗淺認為載客時間和地點可能占極大因素，嘗試找出與業績的關係模型並利用其作為經營策略之參考。

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    """
    請完成這個 Function 後往下執行
    """
    return sum((y - y_hat) ** 2) / len(y)
    
def mean_absolute_error(y, y_hat):
    return sum(abs(y - y_hat)) / len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label='data points')
plt.title("Assume we have data points")
plt.legend(loc=2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label='data')
plt.plot(x_lin, y_hat, 'r-', label='prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc=2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 228.679
# The Mean absolute error is 12.325
