# %% [markdown]
# ## 作業
#
# 1. 請自行定義一個 loss function = 0.3 * focal-loss + 0.7 cross-entropy，並訓練比較結果。

# %% [markdown]
# ## 參考資料
#
# [Focal Loss Function](https://blog.csdn.net/u014380165/article/details/77019084)
#
# [Keras 自定义 Loss Function](https://blog.csdn.net/A_a_ron/article/details/79050204)
#
# [TensorFlow 101：常數、變數與 Placeholder](https://medium.com/datainpoint/tf101-constants-variables-and-placeholders-d36cf13d9e21)

# %%
import itertools
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib import cm, colors
from keras import backend
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.models import Model
from keras.layers import Input, Dense, BatchNormalization
from keras.optimizers import SGD
tf.logging.set_verbosity(tf.logging.ERROR)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 準備資料

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
def normalize_cifar10_data(x, y):
    x = x.reshape((len(x), -1)) / 255.
    y = np_utils.to_categorical(y, num_classes=10)
    return x, y

def normalize_result(x, y):
    print('x.shape:', x.shape)
    print('y.shape:', y.shape)

# %%
print('Before normalization:')
normalize_result(X_train, y_train)
# Out:
# Before normalization:
# x.shape: (50000, 32, 32, 3)
# y.shape: (50000, 1)

# %%
print('After normalization:')
X_train, y_train = normalize_cifar10_data(X_train, y_train)
X_test, y_test = normalize_cifar10_data(X_test, y_test)
normalize_result(X_train, y_train)
# Out:
# After normalization:
# x.shape: (50000, 3072)
# y.shape: (50000, 10)

# %% [markdown]
# ## 定義函數

# %%
def make_custom_loss(alpha=2.0, beta=1.0, gamma=2.0, epsilon=1e-8):

    def custom_loss(y_true, y_pred):
        yt = tf.convert_to_tensor(y_true, tf.float32)
        pt = tf.add(tf.convert_to_tensor(y_pred, tf.float32), epsilon)
        ce = tf.multiply(yt, -tf.log(pt))
        fl = tf.multiply(alpha, tf.multiply(tf.pow(tf.subtract(1., pt), gamma), ce))
        cl = tf.add(tf.multiply(tf.subtract(1., beta), ce), tf.multiply(beta, fl))
        return tf.reduce_mean(tf.reduce_max(cl, axis=1))

    return custom_loss

class Trainer:

    def __init__(self, X_train, y_train, X_test, y_test, build_param, neuron_numbers=(512, 256, 128,),
                 epochs=50, batch_size=1024, momentum=0.95, learning_rate=1e-3):
        self.X_test = X_test
        self.y_test = y_test
        self.X_train = X_train
        self.y_train = y_train
        self.epochs = epochs
        self.batch_size = batch_size
        self.momentum = momentum
        self.learning_rate = learning_rate
        self.neuron_numbers = neuron_numbers
        self.build_param = build_param
        self._model = None
        self._history = None

    @property
    def loss(self):
        alpha = self.build_param.custom_loss_alpha
        beta = self.build_param.custom_loss_beta
        gamma = self.build_param.custom_loss_gamma
        return make_custom_loss(alpha=alpha, beta=beta, gamma=gamma)

    @property
    def optimizer(self):
        return SGD(lr=self.learning_rate, momentum=self.momentum, nesterov=True)

    @property
    def validation_data(self):
        return (self.X_test, self.y_test,)

    def run(self):
        return self._clear()._build()._launch()

    def _clear(self):
        backend.clear_session()
        self._model = None
        return self

    def _build(self):
        main_input = hidden_input = Input(shape=self.X_train.shape[-1:], name='main_input')
        for i, neuron_number in enumerate(self.neuron_numbers):
            hidden_input = Dense(units=neuron_number, activation='relu', name=f'hidden_layer{i}')(hidden_input)
            hidden_input = BatchNormalization()(hidden_input)
        main_output = Dense(units=self.y_train.shape[-1], activation='softmax', name='main_output')(hidden_input)
        self._model = Model(inputs=[main_input], outputs=[main_output])
        self._model.compile(optimizer=self.optimizer, loss=self.loss, metrics=['accuracy'])
        return self

    def _launch(self):
        print('Experiment with label: {}'.format(self.build_param.label))
        self._model.summary()
        self._history = self._model.fit(
            self.X_train, self.y_train, epochs=self.epochs, batch_size=self.batch_size,
            validation_data=self.validation_data, shuffle=True, verbose=2)
        return self

    def display(self, train_name, val_name, color):
        plt.plot(self._history.history[train_name], '-', label='exp: {}'.format(self.build_param.label), color=color)
        plt.plot(self._history.history[val_name], '--', label='exp: {}'.format(self.build_param.label), color=color)

class BuildParam:

    def __init__(self, custom_loss_alpha, custom_loss_beta, custom_loss_gamma):
        self.custom_loss_alpha = custom_loss_alpha
        self.custom_loss_beta = custom_loss_beta
        self.custom_loss_gamma = custom_loss_gamma

    @property
    def label(self):
        return 'α={:.2f}, β={:.2f}, γ={:.2f}'.format(self.custom_loss_alpha, self.custom_loss_beta, self.custom_loss_gamma)

class BatchTrainer:
    
    def __init__(self, trainers):
        self.trainers = trainers
        self.total_amount = len(trainers)

    @property
    def colors(self):
        color_map = cm.ScalarMappable(cmap=plt.get_cmap('gist_rainbow'),
                                      norm=colors.Normalize(vmin=0, vmax=self.total_amount - 1))
        return [color_map.to_rgba(i) for i in range(self.total_amount)]

    def run(self):
        for i in range(self.total_amount):
            self.trainers[i].run()
        return self

    def display(self, train_name, val_name):
        plt.figure(figsize=(12, 7,))
        for i, color in enumerate(self.colors):
            self.trainers[i].display(train_name, val_name, color)
        plt.xlabel('Epoch')
        plt.ylabel(train_name)
        plt.title('Train History')
        plt.legend(loc='center left', bbox_to_anchor=(1, 0.5,))
        plt.show()

# %% [markdown]
# ## 以自訂函數不同的 beta 值觀看學習曲線的走勢

# %%
# 設定超參數
alphas = (2.0,)
betas = (0.0, 0.3, 0.5, 0.7, 1.0,)
gammas = (2.0,)

params = [BuildParam(*args) for args in itertools.product(alphas, betas, gammas)]
trainers = [Trainer(X_train, y_train, X_test, y_test, param) for param in params]

# %%
batch_trainer = BatchTrainer(trainers).run()
# Out:
# Experiment with label: α=2.00, β=0.00, γ=2.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 3072)              0
# _________________________________________________________________
# hidden_layer0 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# main_output (Dense)          (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#  - 10s - loss: 2.2366 - acc: 0.2698 - val_loss: 2.0488 - val_acc: 0.3244
# Epoch 2/50
#  - 9s - loss: 1.7497 - acc: 0.3897 - val_loss: 1.7972 - val_acc: 0.3860
# Epoch 3/50
#  - 8s - loss: 1.6220 - acc: 0.4299 - val_loss: 1.7030 - val_acc: 0.4059
# Epoch 4/50
#  - 9s - loss: 1.5468 - acc: 0.4577 - val_loss: 1.6324 - val_acc: 0.4265
# Epoch 5/50
#  - 9s - loss: 1.4925 - acc: 0.4733 - val_loss: 1.6004 - val_acc: 0.4380
# Epoch 6/50
#  - 9s - loss: 1.4456 - acc: 0.4907 - val_loss: 1.5687 - val_acc: 0.4501
# Epoch 7/50
#  - 8s - loss: 1.4052 - acc: 0.5087 - val_loss: 1.5506 - val_acc: 0.4566
# Epoch 8/50
#  - 9s - loss: 1.3695 - acc: 0.5193 - val_loss: 1.5460 - val_acc: 0.4582
# Epoch 9/50
#  - 9s - loss: 1.3372 - acc: 0.5317 - val_loss: 1.5229 - val_acc: 0.4597
# Epoch 10/50
#  - 9s - loss: 1.3060 - acc: 0.5441 - val_loss: 1.5257 - val_acc: 0.4648
# Epoch 11/50
#  - 9s - loss: 1.2802 - acc: 0.5548 - val_loss: 1.5121 - val_acc: 0.4715
# Epoch 12/50
#  - 8s - loss: 1.2521 - acc: 0.5648 - val_loss: 1.5012 - val_acc: 0.4703
# Epoch 13/50
#  - 8s - loss: 1.2244 - acc: 0.5746 - val_loss: 1.5035 - val_acc: 0.4682
# Epoch 14/50
#  - 8s - loss: 1.2007 - acc: 0.5841 - val_loss: 1.4792 - val_acc: 0.4795
# Epoch 15/50
#  - 8s - loss: 1.1768 - acc: 0.5928 - val_loss: 1.4895 - val_acc: 0.4741
# Epoch 16/50
#  - 8s - loss: 1.1514 - acc: 0.6023 - val_loss: 1.4803 - val_acc: 0.4790
# Epoch 17/50
#  - 8s - loss: 1.1281 - acc: 0.6131 - val_loss: 1.4699 - val_acc: 0.4787
# Epoch 18/50
#  - 8s - loss: 1.1049 - acc: 0.6204 - val_loss: 1.4784 - val_acc: 0.4816
# Epoch 19/50
#  - 9s - loss: 1.0832 - acc: 0.6271 - val_loss: 1.4630 - val_acc: 0.4874
# Epoch 20/50
#  - 9s - loss: 1.0634 - acc: 0.6364 - val_loss: 1.4717 - val_acc: 0.4847
# Epoch 21/50
#  - 11s - loss: 1.0403 - acc: 0.6436 - val_loss: 1.4844 - val_acc: 0.4880
# Epoch 22/50
#  - 10s - loss: 1.0183 - acc: 0.6531 - val_loss: 1.4697 - val_acc: 0.4898
# Epoch 23/50
#  - 9s - loss: 1.0002 - acc: 0.6596 - val_loss: 1.4855 - val_acc: 0.4877
# Epoch 24/50
#  - 10s - loss: 0.9777 - acc: 0.6696 - val_loss: 1.4655 - val_acc: 0.4944
# Epoch 25/50
#  - 9s - loss: 0.9588 - acc: 0.6761 - val_loss: 1.4642 - val_acc: 0.4903
# Epoch 26/50
#  - 9s - loss: 0.9377 - acc: 0.6849 - val_loss: 1.4859 - val_acc: 0.4893
# Epoch 27/50
#  - 9s - loss: 0.9175 - acc: 0.6940 - val_loss: 1.4736 - val_acc: 0.4923
# Epoch 28/50
#  - 8s - loss: 0.8976 - acc: 0.7007 - val_loss: 1.4796 - val_acc: 0.4895
# Epoch 29/50
#  - 9s - loss: 0.8763 - acc: 0.7090 - val_loss: 1.4768 - val_acc: 0.4958
# Epoch 30/50
#  - 9s - loss: 0.8570 - acc: 0.7170 - val_loss: 1.4844 - val_acc: 0.4951
# Epoch 31/50
#  - 9s - loss: 0.8354 - acc: 0.7255 - val_loss: 1.5018 - val_acc: 0.4895
# Epoch 32/50
#  - 9s - loss: 0.8185 - acc: 0.7311 - val_loss: 1.5128 - val_acc: 0.4907
# Epoch 33/50
#  - 9s - loss: 0.7996 - acc: 0.7393 - val_loss: 1.4954 - val_acc: 0.4959
# Epoch 34/50
#  - 9s - loss: 0.7786 - acc: 0.7489 - val_loss: 1.5049 - val_acc: 0.4959
# Epoch 35/50
#  - 9s - loss: 0.7592 - acc: 0.7561 - val_loss: 1.5064 - val_acc: 0.4984
# Epoch 36/50
#  - 9s - loss: 0.7395 - acc: 0.7637 - val_loss: 1.5268 - val_acc: 0.4872
# Epoch 37/50
#  - 9s - loss: 0.7204 - acc: 0.7704 - val_loss: 1.5428 - val_acc: 0.4853
# Epoch 38/50
#  - 9s - loss: 0.7025 - acc: 0.7778 - val_loss: 1.5378 - val_acc: 0.4937
# Epoch 39/50
#  - 9s - loss: 0.6847 - acc: 0.7834 - val_loss: 1.5442 - val_acc: 0.4896
# Epoch 40/50
#  - 9s - loss: 0.6687 - acc: 0.7906 - val_loss: 1.5493 - val_acc: 0.4967
# Epoch 41/50
#  - 9s - loss: 0.6488 - acc: 0.7986 - val_loss: 1.5599 - val_acc: 0.4966
# Epoch 42/50
#  - 9s - loss: 0.6306 - acc: 0.8079 - val_loss: 1.5836 - val_acc: 0.4898
# Epoch 43/50
#  - 9s - loss: 0.6117 - acc: 0.8140 - val_loss: 1.5808 - val_acc: 0.4911
# Epoch 44/50
#  - 9s - loss: 0.5939 - acc: 0.8212 - val_loss: 1.5943 - val_acc: 0.4926
# Epoch 45/50
#  - 9s - loss: 0.5781 - acc: 0.8285 - val_loss: 1.6152 - val_acc: 0.4899
# Epoch 46/50
#  - 9s - loss: 0.5603 - acc: 0.8368 - val_loss: 1.6441 - val_acc: 0.4849
# Epoch 47/50
#  - 9s - loss: 0.5435 - acc: 0.8416 - val_loss: 1.6367 - val_acc: 0.4895
# Epoch 48/50
#  - 9s - loss: 0.5261 - acc: 0.8502 - val_loss: 1.6683 - val_acc: 0.4860
# Epoch 49/50
#  - 9s - loss: 0.5106 - acc: 0.8559 - val_loss: 1.6678 - val_acc: 0.4931
# Epoch 50/50
#  - 8s - loss: 0.4939 - acc: 0.8616 - val_loss: 1.6695 - val_acc: 0.4859
# Experiment with label: α=2.00, β=0.30, γ=2.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 3072)              0
# _________________________________________________________________
# hidden_layer0 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# main_output (Dense)          (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#  - 9s - loss: 2.5246 - acc: 0.2880 - val_loss: 2.3643 - val_acc: 0.3274
# Epoch 2/50
#  - 8s - loss: 1.9284 - acc: 0.4028 - val_loss: 2.0204 - val_acc: 0.3899
# Epoch 3/50
#  - 8s - loss: 1.7752 - acc: 0.4442 - val_loss: 1.8781 - val_acc: 0.4091
# Epoch 4/50
#  - 8s - loss: 1.6910 - acc: 0.4688 - val_loss: 1.8200 - val_acc: 0.4290
# Epoch 5/50
#  - 8s - loss: 1.6216 - acc: 0.4886 - val_loss: 1.7671 - val_acc: 0.4389
# Epoch 6/50
#  - 8s - loss: 1.5648 - acc: 0.5053 - val_loss: 1.7392 - val_acc: 0.4525
# Epoch 7/50
#  - 8s - loss: 1.5161 - acc: 0.5209 - val_loss: 1.7422 - val_acc: 0.4520
# Epoch 8/50
#  - 8s - loss: 1.4712 - acc: 0.5328 - val_loss: 1.6946 - val_acc: 0.4602
# Epoch 9/50
#  - 8s - loss: 1.4296 - acc: 0.5469 - val_loss: 1.6730 - val_acc: 0.4668
# Epoch 10/50
#  - 9s - loss: 1.3905 - acc: 0.5590 - val_loss: 1.6652 - val_acc: 0.4694
# Epoch 11/50
#  - 9s - loss: 1.3546 - acc: 0.5691 - val_loss: 1.6580 - val_acc: 0.4766
# Epoch 12/50
#  - 9s - loss: 1.3208 - acc: 0.5809 - val_loss: 1.6449 - val_acc: 0.4791
# Epoch 13/50
#  - 9s - loss: 1.2903 - acc: 0.5894 - val_loss: 1.6469 - val_acc: 0.4774
# Epoch 14/50
#  - 9s - loss: 1.2585 - acc: 0.6000 - val_loss: 1.6364 - val_acc: 0.4813
# Epoch 15/50
#  - 9s - loss: 1.2260 - acc: 0.6103 - val_loss: 1.6279 - val_acc: 0.4821
# Epoch 16/50
#  - 9s - loss: 1.1943 - acc: 0.6210 - val_loss: 1.6374 - val_acc: 0.4838
# Epoch 17/50
#  - 9s - loss: 1.1649 - acc: 0.6301 - val_loss: 1.6278 - val_acc: 0.4855
# Epoch 18/50
#  - 9s - loss: 1.1370 - acc: 0.6389 - val_loss: 1.6260 - val_acc: 0.4904
# Epoch 19/50
#  - 8s - loss: 1.1082 - acc: 0.6478 - val_loss: 1.6146 - val_acc: 0.4927
# Epoch 20/50
#  - 8s - loss: 1.0785 - acc: 0.6573 - val_loss: 1.6390 - val_acc: 0.4838
# Epoch 21/50
#  - 9s - loss: 1.0523 - acc: 0.6640 - val_loss: 1.6217 - val_acc: 0.4885
# Epoch 22/50
#  - 8s - loss: 1.0251 - acc: 0.6735 - val_loss: 1.6355 - val_acc: 0.4836
# Epoch 23/50
#  - 9s - loss: 1.0019 - acc: 0.6820 - val_loss: 1.6336 - val_acc: 0.4889
# Epoch 24/50
#  - 9s - loss: 0.9748 - acc: 0.6930 - val_loss: 1.6318 - val_acc: 0.4936
# Epoch 25/50
#  - 9s - loss: 0.9477 - acc: 0.7001 - val_loss: 1.6343 - val_acc: 0.4924
# Epoch 26/50
#  - 9s - loss: 0.9205 - acc: 0.7086 - val_loss: 1.6501 - val_acc: 0.4914
# Epoch 27/50
#  - 9s - loss: 0.8961 - acc: 0.7179 - val_loss: 1.6548 - val_acc: 0.4942
# Epoch 28/50
#  - 8s - loss: 0.8704 - acc: 0.7270 - val_loss: 1.6651 - val_acc: 0.4923
# Epoch 29/50
#  - 8s - loss: 0.8426 - acc: 0.7380 - val_loss: 1.6723 - val_acc: 0.4912
# Epoch 30/50
#  - 8s - loss: 0.8206 - acc: 0.7454 - val_loss: 1.6951 - val_acc: 0.4876
# Epoch 31/50
#  - 8s - loss: 0.7965 - acc: 0.7539 - val_loss: 1.7025 - val_acc: 0.4882
# Epoch 32/50
#  - 8s - loss: 0.7728 - acc: 0.7623 - val_loss: 1.6969 - val_acc: 0.4877
# Epoch 33/50
#  - 8s - loss: 0.7474 - acc: 0.7704 - val_loss: 1.7097 - val_acc: 0.4881
# Epoch 34/50
#  - 9s - loss: 0.7254 - acc: 0.7788 - val_loss: 1.7255 - val_acc: 0.4903
# Epoch 35/50
#  - 9s - loss: 0.7009 - acc: 0.7884 - val_loss: 1.7374 - val_acc: 0.4868
# Epoch 36/50
#  - 8s - loss: 0.6774 - acc: 0.7961 - val_loss: 1.7491 - val_acc: 0.4862
# Epoch 37/50
#  - 8s - loss: 0.6539 - acc: 0.8050 - val_loss: 1.7637 - val_acc: 0.4903
# Epoch 38/50
#  - 9s - loss: 0.6347 - acc: 0.8122 - val_loss: 1.7831 - val_acc: 0.4893
# Epoch 39/50
#  - 8s - loss: 0.6113 - acc: 0.8200 - val_loss: 1.7794 - val_acc: 0.4871
# Epoch 40/50
#  - 8s - loss: 0.5920 - acc: 0.8262 - val_loss: 1.8136 - val_acc: 0.4903
# Epoch 41/50
#  - 8s - loss: 0.5696 - acc: 0.8350 - val_loss: 1.8121 - val_acc: 0.4896
# Epoch 42/50
#  - 8s - loss: 0.5503 - acc: 0.8415 - val_loss: 1.8238 - val_acc: 0.4913
# Epoch 43/50
#  - 8s - loss: 0.5319 - acc: 0.8471 - val_loss: 1.8609 - val_acc: 0.4834
# Epoch 44/50
#  - 8s - loss: 0.5117 - acc: 0.8544 - val_loss: 1.8811 - val_acc: 0.4847
# Epoch 45/50
#  - 8s - loss: 0.4927 - acc: 0.8637 - val_loss: 1.8917 - val_acc: 0.4921
# Epoch 46/50
#  - 9s - loss: 0.4731 - acc: 0.8711 - val_loss: 1.9246 - val_acc: 0.4859
# Epoch 47/50
#  - 8s - loss: 0.4537 - acc: 0.8792 - val_loss: 1.9112 - val_acc: 0.4907
# Epoch 48/50
#  - 9s - loss: 0.4345 - acc: 0.8863 - val_loss: 1.9480 - val_acc: 0.4908
# Epoch 49/50
#  - 8s - loss: 0.4210 - acc: 0.8905 - val_loss: 1.9624 - val_acc: 0.4878
# Epoch 50/50
#  - 8s - loss: 0.4044 - acc: 0.8974 - val_loss: 2.0039 - val_acc: 0.4829
# Experiment with label: α=2.00, β=0.50, γ=2.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 3072)              0
# _________________________________________________________________
# hidden_layer0 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# main_output (Dense)          (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#  - 9s - loss: 2.7591 - acc: 0.2920 - val_loss: 2.8309 - val_acc: 0.3180
# Epoch 2/50
#  - 8s - loss: 2.0409 - acc: 0.4111 - val_loss: 2.2339 - val_acc: 0.3848
# Epoch 3/50
#  - 8s - loss: 1.8710 - acc: 0.4509 - val_loss: 2.0033 - val_acc: 0.4265
# Epoch 4/50
#  - 8s - loss: 1.7697 - acc: 0.4752 - val_loss: 1.9572 - val_acc: 0.4356
# Epoch 5/50
#  - 8s - loss: 1.6941 - acc: 0.4954 - val_loss: 1.8796 - val_acc: 0.4484
# Epoch 6/50
#  - 9s - loss: 1.6295 - acc: 0.5122 - val_loss: 1.8432 - val_acc: 0.4566
# Epoch 7/50
#  - 9s - loss: 1.5732 - acc: 0.5262 - val_loss: 1.8166 - val_acc: 0.4620
# Epoch 8/50
#  - 8s - loss: 1.5214 - acc: 0.5404 - val_loss: 1.7848 - val_acc: 0.4716
# Epoch 9/50
#  - 8s - loss: 1.4749 - acc: 0.5511 - val_loss: 1.7755 - val_acc: 0.4715
# Epoch 10/50
#  - 8s - loss: 1.4325 - acc: 0.5644 - val_loss: 1.7648 - val_acc: 0.4755
# Epoch 11/50
#  - 9s - loss: 1.3910 - acc: 0.5757 - val_loss: 1.7438 - val_acc: 0.4808
# Epoch 12/50
#  - 8s - loss: 1.3508 - acc: 0.5861 - val_loss: 1.7285 - val_acc: 0.4873
# Epoch 13/50
#  - 8s - loss: 1.3151 - acc: 0.5963 - val_loss: 1.7243 - val_acc: 0.4898
# Epoch 14/50
#  - 8s - loss: 1.2778 - acc: 0.6074 - val_loss: 1.7295 - val_acc: 0.4851
# Epoch 15/50
#  - 8s - loss: 1.2406 - acc: 0.6181 - val_loss: 1.7629 - val_acc: 0.4816
# Epoch 16/50
#  - 8s - loss: 1.2078 - acc: 0.6270 - val_loss: 1.7081 - val_acc: 0.4916
# Epoch 17/50
#  - 9s - loss: 1.1744 - acc: 0.6377 - val_loss: 1.7138 - val_acc: 0.4964
# Epoch 18/50
#  - 8s - loss: 1.1430 - acc: 0.6460 - val_loss: 1.7203 - val_acc: 0.4915
# Epoch 19/50
#  - 9s - loss: 1.1069 - acc: 0.6588 - val_loss: 1.7423 - val_acc: 0.4882
# Epoch 20/50
#  - 8s - loss: 1.0752 - acc: 0.6666 - val_loss: 1.7312 - val_acc: 0.4905
# Epoch 21/50
#  - 9s - loss: 1.0467 - acc: 0.6756 - val_loss: 1.7313 - val_acc: 0.4888
# Epoch 22/50
#  - 8s - loss: 1.0158 - acc: 0.6846 - val_loss: 1.7551 - val_acc: 0.4929
# Epoch 23/50
#  - 8s - loss: 0.9854 - acc: 0.6949 - val_loss: 1.7438 - val_acc: 0.4964
# Epoch 24/50
#  - 8s - loss: 0.9539 - acc: 0.7044 - val_loss: 1.7575 - val_acc: 0.4930
# Epoch 25/50
#  - 8s - loss: 0.9257 - acc: 0.7131 - val_loss: 1.7702 - val_acc: 0.4904
# Epoch 26/50
#  - 9s - loss: 0.8944 - acc: 0.7231 - val_loss: 1.7903 - val_acc: 0.4888
# Epoch 27/50
#  - 8s - loss: 0.8680 - acc: 0.7311 - val_loss: 1.7806 - val_acc: 0.4934
# Epoch 28/50
#  - 8s - loss: 0.8363 - acc: 0.7425 - val_loss: 1.7918 - val_acc: 0.4902
# Epoch 29/50
#  - 8s - loss: 0.8133 - acc: 0.7476 - val_loss: 1.8249 - val_acc: 0.4905
# Epoch 30/50
#  - 8s - loss: 0.7819 - acc: 0.7595 - val_loss: 1.8282 - val_acc: 0.4898
# Epoch 31/50
#  - 8s - loss: 0.7567 - acc: 0.7667 - val_loss: 1.8588 - val_acc: 0.4922
# Epoch 32/50
#  - 8s - loss: 0.7301 - acc: 0.7759 - val_loss: 1.8656 - val_acc: 0.4892
# Epoch 33/50
#  - 8s - loss: 0.7053 - acc: 0.7839 - val_loss: 1.8972 - val_acc: 0.4860
# Epoch 34/50
#  - 8s - loss: 0.6789 - acc: 0.7936 - val_loss: 1.8965 - val_acc: 0.4868
# Epoch 35/50
#  - 9s - loss: 0.6545 - acc: 0.8031 - val_loss: 1.8952 - val_acc: 0.4898
# Epoch 36/50
#  - 9s - loss: 0.6284 - acc: 0.8103 - val_loss: 1.9050 - val_acc: 0.4926
# Epoch 37/50
#  - 9s - loss: 0.6020 - acc: 0.8206 - val_loss: 1.9214 - val_acc: 0.4873
# Epoch 38/50
#  - 9s - loss: 0.5813 - acc: 0.8265 - val_loss: 1.9598 - val_acc: 0.4891
# Epoch 39/50
#  - 9s - loss: 0.5597 - acc: 0.8347 - val_loss: 1.9896 - val_acc: 0.4770
# Epoch 40/50
#  - 8s - loss: 0.5352 - acc: 0.8432 - val_loss: 1.9938 - val_acc: 0.4899
# Epoch 41/50
#  - 8s - loss: 0.5156 - acc: 0.8508 - val_loss: 2.0032 - val_acc: 0.4854
# Epoch 42/50
#  - 9s - loss: 0.4925 - acc: 0.8592 - val_loss: 2.0516 - val_acc: 0.4804
# Epoch 43/50
#  - 8s - loss: 0.4719 - acc: 0.8660 - val_loss: 2.0340 - val_acc: 0.4926
# Epoch 44/50
#  - 9s - loss: 0.4545 - acc: 0.8718 - val_loss: 2.0613 - val_acc: 0.4898
# Epoch 45/50
#  - 9s - loss: 0.4372 - acc: 0.8777 - val_loss: 2.0891 - val_acc: 0.4845
# Epoch 46/50
#  - 9s - loss: 0.4156 - acc: 0.8876 - val_loss: 2.1346 - val_acc: 0.4838
# Epoch 47/50
#  - 9s - loss: 0.3979 - acc: 0.8912 - val_loss: 2.1224 - val_acc: 0.4866
# Epoch 48/50
#  - 9s - loss: 0.3787 - acc: 0.8999 - val_loss: 2.1493 - val_acc: 0.4874
# Epoch 49/50
#  - 8s - loss: 0.3613 - acc: 0.9064 - val_loss: 2.1985 - val_acc: 0.4861
# Epoch 50/50
#  - 9s - loss: 0.3461 - acc: 0.9128 - val_loss: 2.1795 - val_acc: 0.4884
# Experiment with label: α=2.00, β=0.70, γ=2.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 3072)              0
# _________________________________________________________________
# hidden_layer0 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# main_output (Dense)          (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#  - 9s - loss: 2.9518 - acc: 0.2937 - val_loss: 2.9130 - val_acc: 0.3211
# Epoch 2/50
#  - 8s - loss: 2.1726 - acc: 0.4126 - val_loss: 2.2624 - val_acc: 0.4051
# Epoch 3/50
#  - 9s - loss: 1.9773 - acc: 0.4525 - val_loss: 2.1399 - val_acc: 0.4137
# Epoch 4/50
#  - 8s - loss: 1.8596 - acc: 0.4812 - val_loss: 2.0409 - val_acc: 0.4342
# Epoch 5/50
#  - 8s - loss: 1.7727 - acc: 0.5012 - val_loss: 1.9800 - val_acc: 0.4465
# Epoch 6/50
#  - 8s - loss: 1.6989 - acc: 0.5182 - val_loss: 1.9286 - val_acc: 0.4481
# Epoch 7/50
#  - 8s - loss: 1.6353 - acc: 0.5324 - val_loss: 1.8998 - val_acc: 0.4651
# Epoch 8/50
#  - 8s - loss: 1.5809 - acc: 0.5486 - val_loss: 1.8782 - val_acc: 0.4670
# Epoch 9/50
#  - 8s - loss: 1.5251 - acc: 0.5601 - val_loss: 1.8658 - val_acc: 0.4680
# Epoch 10/50
#  - 9s - loss: 1.4756 - acc: 0.5732 - val_loss: 1.8788 - val_acc: 0.4711
# Epoch 11/50
#  - 8s - loss: 1.4265 - acc: 0.5838 - val_loss: 1.8557 - val_acc: 0.4765
# Epoch 12/50
#  - 8s - loss: 1.3803 - acc: 0.5953 - val_loss: 1.8237 - val_acc: 0.4827
# Epoch 13/50
#  - 8s - loss: 1.3387 - acc: 0.6069 - val_loss: 1.8302 - val_acc: 0.4833
# Epoch 14/50
#  - 8s - loss: 1.2981 - acc: 0.6147 - val_loss: 1.8204 - val_acc: 0.4807
# Epoch 15/50
#  - 8s - loss: 1.2586 - acc: 0.6260 - val_loss: 1.8162 - val_acc: 0.4881
# Epoch 16/50
#  - 9s - loss: 1.2173 - acc: 0.6351 - val_loss: 1.8316 - val_acc: 0.4817
# Epoch 17/50
#  - 9s - loss: 1.1789 - acc: 0.6455 - val_loss: 1.8151 - val_acc: 0.4896
# Epoch 18/50
#  - 9s - loss: 1.1427 - acc: 0.6542 - val_loss: 1.8702 - val_acc: 0.4802
# Epoch 19/50
#  - 9s - loss: 1.1058 - acc: 0.6653 - val_loss: 1.8204 - val_acc: 0.4912
# Epoch 20/50
#  - 9s - loss: 1.0664 - acc: 0.6759 - val_loss: 1.8431 - val_acc: 0.4901
# Epoch 21/50
#  - 10s - loss: 1.0299 - acc: 0.6879 - val_loss: 1.8392 - val_acc: 0.4905
# Epoch 22/50
#  - 9s - loss: 0.9974 - acc: 0.6951 - val_loss: 1.8515 - val_acc: 0.4872
# Epoch 23/50
#  - 9s - loss: 0.9619 - acc: 0.7063 - val_loss: 1.8624 - val_acc: 0.4884
# Epoch 24/50
#  - 9s - loss: 0.9287 - acc: 0.7157 - val_loss: 1.9182 - val_acc: 0.4812
# Epoch 25/50
#  - 9s - loss: 0.8969 - acc: 0.7257 - val_loss: 1.9050 - val_acc: 0.4938
# Epoch 26/50
#  - 9s - loss: 0.8623 - acc: 0.7352 - val_loss: 1.9252 - val_acc: 0.4870
# Epoch 27/50
#  - 9s - loss: 0.8303 - acc: 0.7440 - val_loss: 1.9167 - val_acc: 0.4883
# Epoch 28/50
#  - 9s - loss: 0.7998 - acc: 0.7544 - val_loss: 1.9356 - val_acc: 0.4823
# Epoch 29/50
#  - 9s - loss: 0.7698 - acc: 0.7611 - val_loss: 1.9719 - val_acc: 0.4862
# Epoch 30/50
#  - 9s - loss: 0.7362 - acc: 0.7720 - val_loss: 1.9529 - val_acc: 0.4895
# Epoch 31/50
#  - 9s - loss: 0.7070 - acc: 0.7803 - val_loss: 2.0050 - val_acc: 0.4872
# Epoch 32/50
#  - 9s - loss: 0.6778 - acc: 0.7916 - val_loss: 2.0059 - val_acc: 0.4847
# Epoch 33/50
#  - 9s - loss: 0.6493 - acc: 0.7993 - val_loss: 1.9984 - val_acc: 0.4859
# Epoch 34/50
#  - 9s - loss: 0.6205 - acc: 0.8101 - val_loss: 2.0246 - val_acc: 0.4789
# Epoch 35/50
#  - 9s - loss: 0.5962 - acc: 0.8176 - val_loss: 2.0348 - val_acc: 0.4833
# Epoch 36/50
#  - 9s - loss: 0.5679 - acc: 0.8275 - val_loss: 2.1173 - val_acc: 0.4804
# Epoch 37/50
#  - 9s - loss: 0.5416 - acc: 0.8364 - val_loss: 2.1370 - val_acc: 0.4712
# Epoch 38/50
#  - 9s - loss: 0.5192 - acc: 0.8426 - val_loss: 2.1207 - val_acc: 0.4912
# Epoch 39/50
#  - 9s - loss: 0.4953 - acc: 0.8524 - val_loss: 2.1561 - val_acc: 0.4827
# Epoch 40/50
#  - 9s - loss: 0.4695 - acc: 0.8610 - val_loss: 2.1696 - val_acc: 0.4841
# Epoch 41/50
#  - 9s - loss: 0.4479 - acc: 0.8681 - val_loss: 2.1977 - val_acc: 0.4766
# Epoch 42/50
#  - 9s - loss: 0.4284 - acc: 0.8736 - val_loss: 2.2779 - val_acc: 0.4825
# Epoch 43/50
#  - 9s - loss: 0.4074 - acc: 0.8812 - val_loss: 2.2347 - val_acc: 0.4814
# Epoch 44/50
#  - 9s - loss: 0.3853 - acc: 0.8905 - val_loss: 2.2592 - val_acc: 0.4801
# Epoch 45/50
#  - 9s - loss: 0.3684 - acc: 0.8957 - val_loss: 2.2989 - val_acc: 0.4763
# Epoch 46/50
#  - 9s - loss: 0.3491 - acc: 0.9022 - val_loss: 2.3381 - val_acc: 0.4721
# Epoch 47/50
#  - 9s - loss: 0.3336 - acc: 0.9082 - val_loss: 2.3498 - val_acc: 0.4753
# Epoch 48/50
#  - 10s - loss: 0.3138 - acc: 0.9173 - val_loss: 2.3756 - val_acc: 0.4704
# Epoch 49/50
#  - 10s - loss: 0.2967 - acc: 0.9233 - val_loss: 2.3940 - val_acc: 0.4840
# Epoch 50/50
#  - 9s - loss: 0.2828 - acc: 0.9273 - val_loss: 2.3846 - val_acc: 0.4824
# Experiment with label: α=2.00, β=1.00, γ=2.00
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# main_input (InputLayer)      (None, 3072)              0
# _________________________________________________________________
# hidden_layer0 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# main_output (Dense)          (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
#  - 10s - loss: 3.3044 - acc: 0.2981 - val_loss: 3.3703 - val_acc: 0.3199
# Epoch 2/50
#  - 9s - loss: 2.3454 - acc: 0.4173 - val_loss: 2.4864 - val_acc: 0.4007
# Epoch 3/50
#  - 9s - loss: 2.1229 - acc: 0.4609 - val_loss: 2.2892 - val_acc: 0.4309
# Epoch 4/50
#  - 9s - loss: 1.9902 - acc: 0.4841 - val_loss: 2.1681 - val_acc: 0.4489
# Epoch 5/50
#  - 9s - loss: 1.8901 - acc: 0.5064 - val_loss: 2.1326 - val_acc: 0.4526
# Epoch 6/50
#  - 9s - loss: 1.8019 - acc: 0.5214 - val_loss: 2.0864 - val_acc: 0.4603
# Epoch 7/50
#  - 9s - loss: 1.7319 - acc: 0.5383 - val_loss: 2.0716 - val_acc: 0.4620
# Epoch 8/50
#  - 9s - loss: 1.6609 - acc: 0.5513 - val_loss: 1.9988 - val_acc: 0.4778
# Epoch 9/50
#  - 9s - loss: 1.5948 - acc: 0.5654 - val_loss: 1.9966 - val_acc: 0.4797
# Epoch 10/50
#  - 9s - loss: 1.5360 - acc: 0.5779 - val_loss: 2.0122 - val_acc: 0.4702
# Epoch 11/50
#  - 9s - loss: 1.4774 - acc: 0.5905 - val_loss: 1.9823 - val_acc: 0.4837
# Epoch 12/50
#  - 9s - loss: 1.4273 - acc: 0.6019 - val_loss: 2.0040 - val_acc: 0.4788
# Epoch 13/50
#  - 9s - loss: 1.3784 - acc: 0.6106 - val_loss: 1.9903 - val_acc: 0.4879
# Epoch 14/50
#  - 9s - loss: 1.3241 - acc: 0.6242 - val_loss: 1.9511 - val_acc: 0.4885
# Epoch 15/50
#  - 9s - loss: 1.2756 - acc: 0.6351 - val_loss: 1.9621 - val_acc: 0.4877
# Epoch 16/50
#  - 9s - loss: 1.2273 - acc: 0.6469 - val_loss: 1.9513 - val_acc: 0.4921
# Epoch 17/50
#  - 9s - loss: 1.1811 - acc: 0.6578 - val_loss: 1.9541 - val_acc: 0.4901
# Epoch 18/50
#  - 9s - loss: 1.1368 - acc: 0.6687 - val_loss: 1.9697 - val_acc: 0.4886
# Epoch 19/50
#  - 9s - loss: 1.0921 - acc: 0.6774 - val_loss: 1.9899 - val_acc: 0.4889
# Epoch 20/50
#  - 9s - loss: 1.0496 - acc: 0.6879 - val_loss: 1.9637 - val_acc: 0.4950
# Epoch 21/50
#  - 9s - loss: 1.0095 - acc: 0.6978 - val_loss: 1.9972 - val_acc: 0.4896
# Epoch 22/50
#  - 9s - loss: 0.9665 - acc: 0.7089 - val_loss: 2.0466 - val_acc: 0.4825
# Epoch 23/50
#  - 9s - loss: 0.9261 - acc: 0.7222 - val_loss: 2.0445 - val_acc: 0.4815
# Epoch 24/50
#  - 9s - loss: 0.8838 - acc: 0.7296 - val_loss: 2.0304 - val_acc: 0.4907
# Epoch 25/50
#  - 8s - loss: 0.8442 - acc: 0.7420 - val_loss: 2.0837 - val_acc: 0.4797
# Epoch 26/50
#  - 9s - loss: 0.8096 - acc: 0.7500 - val_loss: 2.0780 - val_acc: 0.4831
# Epoch 27/50
#  - 9s - loss: 0.7684 - acc: 0.7619 - val_loss: 2.1059 - val_acc: 0.4850
# Epoch 28/50
#  - 9s - loss: 0.7305 - acc: 0.7718 - val_loss: 2.1150 - val_acc: 0.4903
# Epoch 29/50
#  - 9s - loss: 0.6911 - acc: 0.7832 - val_loss: 2.1380 - val_acc: 0.4855
# Epoch 30/50
#  - 9s - loss: 0.6592 - acc: 0.7917 - val_loss: 2.1454 - val_acc: 0.4984
# Epoch 31/50
#  - 8s - loss: 0.6232 - acc: 0.8024 - val_loss: 2.1717 - val_acc: 0.4878
# Epoch 32/50
#  - 9s - loss: 0.5917 - acc: 0.8117 - val_loss: 2.2367 - val_acc: 0.4815
# Epoch 33/50
#  - 9s - loss: 0.5598 - acc: 0.8207 - val_loss: 2.2464 - val_acc: 0.4846
# Epoch 34/50
#  - 9s - loss: 0.5293 - acc: 0.8301 - val_loss: 2.2908 - val_acc: 0.4828
# Epoch 35/50
#  - 8s - loss: 0.5012 - acc: 0.8391 - val_loss: 2.3275 - val_acc: 0.4745
# Epoch 36/50
#  - 8s - loss: 0.4701 - acc: 0.8500 - val_loss: 2.3213 - val_acc: 0.4779
# Epoch 37/50
#  - 8s - loss: 0.4429 - acc: 0.8582 - val_loss: 2.3097 - val_acc: 0.4851
# Epoch 38/50
#  - 8s - loss: 0.4182 - acc: 0.8643 - val_loss: 2.3671 - val_acc: 0.4838
# Epoch 39/50
#  - 8s - loss: 0.3902 - acc: 0.8750 - val_loss: 2.3965 - val_acc: 0.4798
# Epoch 40/50
#  - 8s - loss: 0.3665 - acc: 0.8830 - val_loss: 2.4230 - val_acc: 0.4810
# Epoch 41/50
#  - 8s - loss: 0.3458 - acc: 0.8892 - val_loss: 2.4638 - val_acc: 0.4743
# Epoch 42/50
#  - 8s - loss: 0.3222 - acc: 0.8992 - val_loss: 2.4540 - val_acc: 0.4830
# Epoch 43/50
#  - 8s - loss: 0.3037 - acc: 0.9049 - val_loss: 2.4881 - val_acc: 0.4828
# Epoch 44/50
#  - 8s - loss: 0.2801 - acc: 0.9136 - val_loss: 2.5355 - val_acc: 0.4822
# Epoch 45/50
#  - 9s - loss: 0.2614 - acc: 0.9209 - val_loss: 2.5176 - val_acc: 0.4788
# Epoch 46/50
#  - 9s - loss: 0.2432 - acc: 0.9272 - val_loss: 2.6005 - val_acc: 0.4820
# Epoch 47/50
#  - 9s - loss: 0.2258 - acc: 0.9326 - val_loss: 2.5969 - val_acc: 0.4792
# Epoch 48/50
#  - 9s - loss: 0.2111 - acc: 0.9390 - val_loss: 2.6057 - val_acc: 0.4758
# Epoch 49/50
#  - 8s - loss: 0.1994 - acc: 0.9419 - val_loss: 2.6688 - val_acc: 0.4745
# Epoch 50/50
#  - 8s - loss: 0.1857 - acc: 0.9472 - val_loss: 2.6987 - val_acc: 0.4749

# %%
batch_trainer.display('acc', 'val_acc')

# %%
batch_trainer.display('loss', 'val_loss')
